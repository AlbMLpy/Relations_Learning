# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import general_functions as gf

# %%
path_wrcp = "Link_Prediction_Factors/"

wrcp_fb237 = pd.read_csv(path_wrcp + "FB15K237/results.csv")
wrcp_fb15k = pd.read_csv(path_wrcp + "FB15K/results.csv")

wrcp_wnrr = pd.read_csv(path_wrcp + "WN18RR/results.csv")
wrcp_wn18 = pd.read_csv(path_wrcp + "WN18/results.csv")

# %%
path_cp = "CP_ALS3/Results/"

cp_fb237 = pd.read_csv(path_cp + "CP_FB15k-237_results.csv")
cp_fb15k = pd.read_csv(path_cp + "CP_FB15k_results.csv")

#cp_wnrr = pd.read_csv(path_cp + "")
#cp_wn18 = pd.read_csv(path_cp + "")

# %%
#path_gcp = ""

#gcp_fb237 = pd.read_csv(path_gcp + "")
#gcp_fb15k = pd.read_csv(path_gcp + "")

#gcp_wnrr = pd.read_csv(path_gcp + "")
#gcp_wn18 = pd.read_csv(path_gcp + "")

# %%
color1 = "#8b0a50"#'tab:red' #"#8b0a50"
color2 = 'tab:blue' #"#1c9b70" 
plt.plot(
    wrcp_fb237["rank"],
    wrcp_fb237["hr10_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
plt.plot(
    cp_fb237["rank"],
    cp_fb237["hr10_test"],
    '-*', c=color2, label='CP-ALS3',
)
plt.grid()
plt.xlabel('Rank')
plt.ylabel('HR@10')
plt.title("FB15k-237")
plt.legend()

# %%
color1 = 'tab:red' #"#8b0a50"
color2 = 'tab:blue' #"#1c9b70" 
plt.plot(
    wrcp_fb15k["rank"],
    wrcp_fb15k["hr10_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
plt.plot(
    cp_fb15k["rank"],
    cp_fb15k["hr10_test"],
    '-*', c=color2, label='CP-ALS3',
)
plt.grid()
plt.xlabel('Rank')
plt.ylabel('HR@10')
plt.title("FB15k")
plt.legend()

# %%
color1 = 'tab:red' #"#8b0a50"
color2 = 'tab:blue' #"#1c9b70" 
plt.plot(
    wrcp_fb237["rank"],
    wrcp_fb237["mrr_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
plt.plot(
    cp_fb237["rank"],
    cp_fb237["mrr_test"],
    '-*', c=color2, label='CP-ALS3',
)
plt.grid()
plt.xlabel('Rank')
plt.ylabel('MRR')
plt.title("FB15k-237")
plt.legend()

# %%
color1 = 'tab:red' #"#8b0a50"
color2 = 'tab:blue' #"#1c9b70" 
plt.plot(
    wrcp_fb15k["rank"],
    wrcp_fb15k["mrr_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
plt.plot(
    cp_fb15k["rank"],
    cp_fb15k["mrr_test"],
    '-*', c=color2, label='CP-ALS3',
)
plt.grid()
plt.xlabel('Rank')
plt.ylabel('MRR')
plt.title("FB15k")
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle("FB15k-237")
fig.set_size_inches(12, 6)

color1 = 'tab:red'#'tab:red' #"#8b0a50"
color2 = 'tab:blue' #'tab:blue' "#1c9b70" 
ax1.plot(
    wrcp_fb237["rank"],
    wrcp_fb237["hr10_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
ax1.plot(
    cp_fb237["rank"],
    cp_fb237["hr10_test"],
    '-*', c=color2, label='CP-ALS3',
)
ax1.grid()
ax1.set_xlabel('Rank')
ax1.set_ylabel('HR@10')
#ax1.set_title("FB15k-237")
ax1.legend()

ax2.plot(
    wrcp_fb237["rank"],
    wrcp_fb237["mrr_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
ax2.plot(
    cp_fb237["rank"],
    cp_fb237["mrr_test"],
    '-*', c=color2, label='CP-ALS3',
)
ax2.grid()
ax2.set_xlabel('Rank')
ax2.set_ylabel('MRR')
#ax2.set_title("FB15k-237")
ax2.legend()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle("FB15k")
fig.set_size_inches(12, 6)

color1 = 'tab:red'#'tab:red' #"#8b0a50"
color2 = 'tab:blue' #'tab:blue' "#1c9b70" 
ax1.plot(
    wrcp_fb15k["rank"],
    wrcp_fb15k["hr10_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
ax1.plot(
    cp_fb15k["rank"],
    cp_fb15k["hr10_test"],
    '-*', c=color2, label='CP-ALS3',
)
ax1.grid()
ax1.set_xlabel('Rank')
ax1.set_ylabel('HR@10')
#ax1.set_title("FB15k-237")
ax1.legend()

ax2.plot(
    wrcp_fb15k["rank"],
    wrcp_fb15k["mrr_test"],
    '-*', c=color1, label='WRCP-ALS3',
)
ax2.plot(
    cp_fb15k["rank"],
    cp_fb15k["mrr_test"],
    '-*', c=color2, label='CP-ALS3',
)
ax2.grid()
ax2.set_xlabel('Rank')
ax2.set_ylabel('MRR')
#ax2.set_title("FB15k-237")
ax2.legend()

# %%
import pickle
path_factors = "Link_Prediction_Factors/FB15K237/"

a = pickle.load(open(path_factors + 'A_factor', 'rb'))
b = pickle.load(open(path_factors + 'B_factor', 'rb'))
c = pickle.load(open(path_factors + 'C_factor', 'rb'))
err = pickle.load(open(path_factors + 'Errors', 'rb'))

# %%
import numpy as np
from sklearn.manifold import TSNE
a_embedded = TSNE(n_components=2).fit_transform(a)
a_embedded.shape
# Out:
# (14206, 2)

# %%
a_embedded
# Out:
# array([[ 28.397095 ,  11.941258 ],
#        [-59.306576 ,  57.91623  ],
#        [ 17.926548 ,  31.371326 ],
#        ...,
#        [  4.4397836, -30.73034  ],
#        [ -3.2837644,  49.168545 ],
#        [-66.83204  , -31.476656 ]], dtype=float32)

# %%
import seaborn as sns
df_subset_a = pd.DataFrame()
df_subset_a['tsne-2d-one'] = a_embedded[:,0]
df_subset_a['tsne-2d-two'] = a_embedded[:,1]

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    palette=sns.color_palette("hls", 10),
    data=df_subset_a,
    legend="full",
    alpha=0.3
)

# %%
b_embedded = TSNE(n_components=2).fit_transform(b)

# %%
df_subset_b = pd.DataFrame()
df_subset_b['tsne-2d-one'] = b_embedded[:,0]
df_subset_b['tsne-2d-two'] = b_embedded[:,1]

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    palette=sns.color_palette("hls", 10),
    data=df_subset_b,
    legend="full",
    alpha=0.3
)

# %%
a.shape
# Out:
# (14206, 700)

# %%
import matplotlib.pyplot as plt
# Create some mock data
x = range(5, 101, 5)
#range(0, 20)
#range(5, 101, 5)
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Rank')
ax1.set_ylabel('HR@10', color=color)
ax1.plot(x, svd_scores1, color=color, linestyle='-', marker='*', label='HR@10')
ax1.tick_params(axis='y', labelcolor=color)
ax1.xaxis.grid(True, linestyle=':')
ax1.set_xticks(range(5, 101, 5))
ax1.legend(loc=2)

ax1.set_title("PureSVD model/ Yahoo data")

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('ARHR@10', color=color)  # we already handled the x-label with ax1
ax2.tick_params(axis='y', labelcolor=color)
ax2.plot(x, svd_scores2, color=color, linestyle='-', marker='*', label='ARHR@10')
ax2.legend(loc=0)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
fig.savefig(
    '/home/albert/Desktop/Diploma_Course_paper/my_course_work(6_semester)/pics/PureSVD_Yahoo',
    dpi=700,
)
plt.show()
